# %% [markdown]
# # **Cluster Analysis**

# %% [markdown]
# Dataset from: https://www.kaggle.com/competitions/tabular-playground-series-jul-2022

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
from kneed import KneeLocator
from sklearn.decomposition import PCA

# %%
df = pd.read_csv('data.csv')

print('Number of data points = {}'.format(df.shape[0]))
print('Shape: {}'.format(df.shape))
print('Columns: {}'.format(list(df.columns)))
# Out:
# Number of data points = 98000
# Shape: (98000, 30)
# Columns: ['id', 'f_00', 'f_01', 'f_02', 'f_03', 'f_04', 'f_05', 'f_06', 'f_07', 'f_08', 'f_09', 'f_10', 'f_11', 'f_12', 'f_13', 'f_14', 'f_15', 'f_16', 'f_17', 'f_18', 'f_19', 'f_20', 'f_21', 'f_22', 'f_23', 'f_24', 'f_25', 'f_26', 'f_27', 'f_28']

# %%
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98000 entries, 0 to 97999
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      98000 non-null  int64
#  1   f_00    98000 non-null  float64
#  2   f_01    98000 non-null  float64
#  3   f_02    98000 non-null  float64
#  4   f_03    98000 non-null  float64
#  5   f_04    98000 non-null  float64
#  6   f_05    98000 non-null  float64
#  7   f_06    98000 non-null  float64
#  8   f_07    98000 non-null  int64
#  9   f_08    98000 non-null  int64
#  10  f_09    98000 non-null  int64
#  11  f_10    98000 non-null  int64
#  12  f_11    98000 non-null  int64
#  13  f_12    98000 non-null  int64
#  14  f_13    98000 non-null  int64
#  15  f_14    98000 non-null  float64
#  16  f_15    98000 non-null  float64
#  17  f_16    98000 non-null  float64
#  18  f_17    98000 non-null  float64
#  19  f_18    98000 non-null  float64
#  20  f_19    98000 non-null  float64
# ...

# %%
df.describe()
# Out:
#                  id          f_00          f_01          f_02          f_03  \
# count  98000.000000  98000.000000  98000.000000  98000.000000  98000.000000
# mean   48999.500000      0.001220      0.005580     -0.001042     -0.000700
# std    28290.307527      1.002801      1.000742      1.001373      1.000422
# min        0.000000     -4.732235     -4.202795     -4.377021     -4.010826
# 25%    24499.750000     -0.675226     -0.670985     -0.672779     -0.672540
# 50%    48999.500000      0.002022      0.006650     -0.000324     -0.003185
# 75%    73499.250000      0.677271      0.677746      0.677086      0.672097
# max    97999.000000      4.490521      4.324974      4.560247      4.399373
#
#                f_04          f_05          f_06          f_07          f_08  \
# count  98000.000000  98000.000000  98000.000000  98000.000000  98000.000000
# mean      -0.003522     -0.001612     -0.003042      5.545918      6.763061
# ...

# %%
scaler = StandardScaler()
columns = df.columns.to_list()
columns = columns[1:]
X = df[columns]
X_scaled = scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, index=df.index, columns=columns)
X_scaled.head()
# Out:
#        f_00      f_01      f_02      f_03      f_04      f_05      f_06  \
# 0 -0.389551 -0.917695  0.649105  0.589499 -0.824775  0.734849  2.267432
# 1 -0.688544 -0.459195  0.654321  0.995533 -1.644472  0.864967 -0.087835
# 2  0.805607  0.318753 -1.167963 -0.623531  0.108638  0.785146  1.996476
# 3 -0.500743  0.223305  0.264788  0.232124  0.417259 -1.219016  0.142257
# 4 -0.670613 -1.044343 -0.268745 -1.828801 -0.285713 -1.850223  0.786963
#
#        f_07      f_08      f_09  ...      f_19      f_20      f_21      f_22  \
# 0 -0.960479  1.502035  0.983395  ... -0.471839 -0.754257 -0.762195 -0.711585
# 1 -0.960479 -0.906254 -0.371415  ... -0.422434 -0.089129 -1.783073 -0.541815
# 2 -0.147872  1.020377 -0.540766  ... -0.407243 -1.597140  1.193015  2.236943
# 3  0.122997 -1.147082  0.814044  ...  0.621083  1.284518  0.534669  0.727667
# 4  0.664735  0.057062 -0.540766  ... -1.617255 -0.433152  0.324273  0.218614
#
#        f_23      f_24      f_25      f_26      f_27      f_28
# ...

# %%
columns = df.columns.to_list()
pca = PCA(2)
X_reduced = pca.fit_transform(X_scaled)
X_reduced = pd.DataFrame(X_reduced, index=df['id'], columns=['x', 'y'])
X_reduced
# Out:
#               x         y
# id
# 0     -0.725057  0.051407
# 1     -1.015880  0.950212
# 2     -1.357768 -0.787178
# 3      1.228103 -0.249732
# 4     -1.005086  0.135224
# ...         ...       ...
# 97995 -0.265254 -0.108736
# 97996 -1.954425  0.886385
# 97997  0.524078  0.886635
# 97998  0.594470  1.112721
# 97999 -1.675399  0.769777
#
# [98000 rows x 2 columns]

# %%
plt.scatter(X_reduced['x'], X_reduced['y'])
plt.show()

# %%
sse = []
for k in range(1, 11):
   kmeans = KMeans(n_clusters=k, random_state=42)
   kmeans.fit(X_reduced)
   sse.append(kmeans.inertia_)

plt.plot(range(1, 11), sse)
plt.xticks(range(1, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.show()

# %%
kl = KneeLocator(range(1, 11), sse, curve="convex", direction="decreasing")
n_clusters = kl.elbow
n_clusters
# Out:
# 3

# %%
model = KMeans(n_clusters=n_clusters, random_state=42)
model.fit(X_reduced)
clusters = pd.unique(model.labels_)
clusters
# Out:
# array([2, 1, 0])

# %%
y = model.predict(X_reduced)
X_reduced['cluster'] = y
prediction = pd.DataFrame(y, index=df['id'], columns=['Predicted'])
prediction
# Out:
#        Predicted
# id
# 0              2
# 1              2
# 2              1
# 3              0
# 4              2
# ...          ...
# 97995          1
# 97996          2
# 97997          0
# 97998          0
# 97999          2
#
# [98000 rows x 1 columns]

# %%
plt.scatter(X_reduced['x'], X_reduced['y'], c=X_reduced['cluster'])
plt.show()
